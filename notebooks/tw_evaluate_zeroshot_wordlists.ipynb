# %%
from fairseq.models.roberta import RobertaModel
from src import evaluate_zeroshot_wordlist

# %%
berdt = RobertaModel.from_pretrained(
    '../models/berdt',
    checkpoint_file='model.pt'
)
berdt.eval()
print("berdt is loaded")
# Out:
# loading archive file ../models/berdt
# | dictionary: 50264 types
# berdt is loaded

# %%
die_dat_correct, die_dat_total = evaluate_zeroshot_wordlist.evaluate(["die", "dat"], model=berdt, print_step=1000)
print("Die/Dat:", die_dat_correct/die_dat_total)
# Out:
# 98.50% / 985 / 1000 / die / die / Mijn fractie en ik hopen dat de financiële grondslag van de Unie de weg zal bereiden voor een Europese rechtsorde die de rechten en de garanties van de burgers eerbiedigt, dat wil zeggen een rechtsorde met garanties <mask> in vele staten nu helaas nog onvoldoende aanwezig zijn.
# 98.40% / 1968 / 2000 / die / die / In Griekenland stellen wij - zoals blijkt uit de gegevens <mask> ik hier heb - een stijging vast van het werkgelegenheidspercentage en de productiviteit.
# 98.47% / 2954 / 3000 / dat / dat / Volgens onze eerste interpretatie laat artikel 255 hoe dan ook niet toe <mask> een rechtsgrond gebruikt wordt die gevolgen kan hebben voor het subsidiariteitsbeginsel.
# 98.28% / 3931 / 4000 / dat / dat / Toch ben ik van mening <mask> we op basis van het mandaat van Helsinki aan de slag kunnen . Ik had dit overigens al vlak na de Top van Helsinki in de Commissie constitutionele zaken te kennen gegeven.
# 98.14% / 4907 / 5000 / dat / dat / Ik reken erop dat we in de reconciliatie tot een uitstekend resultaat komen en <mask> de inzet voor een beter leefmilieu het haalt op onredelijke industriële eisen.
# 98.23% / 5894 / 6000 / dat / die / Hervorming is belangrijk maar als deze alles in duigen doet vallen en de supranationale bevoegdheden van de Commissie ondermijnt, zal zij de grondslag van de Europese integratie aantasten en <mask> onderuit halen wat de oprichters van de Europese Gemeenschap met betrekking tot de Europese Commissie voor ogen stond.
# 98.10% / 6867 / 7000 / die / die / In het noorden van Europa ziet de situatie er heel anders uit dan in het zuiden terwijl die landen <mask> te maken hebben met woestijnvorming op hun beurt weer met andere problemen te kampen hebben.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-cc73d0785c8d> in <module>
# ----> 1 die_dat_correct, die_dat_total = evaluate_zeroshot_wordlist.evaluate(["die", "dat"], model=berdt, print_step=1000)
#       2 print("Die/Dat:", die_dat_correct/die_dat_total)
#       3
#
# ~/Repositories/berdt/src/evaluate_zeroshot_wordlist.py in evaluate(words, path, model, print_step)
#      34
#      35             try:
# ---> 36                 predicted = wordlistfiller.find_optimal_word(sentence)
#      37                 if predicted is None:
#      38                     errors += 1
#
# ~/Repositories/berdt/src/wordlistfiller.py in find_optimal_word(self, text)
#      23         result = None
#      24         while result is None and topk <= self._top_k_limit:
# ---> 25             filler_words = self._model.fill_mask(text, topk=topk)
#      26             result = next((x[2].strip() for x in filler_words if x[2].lower() in self._target_words_spaced), None)
#      27             topk *= 2
#
# /usr/local/lib/python3.6/dist-packages/fairseq/models/roberta/hub_interface.py in fill_mask(self, masked_input, topk)
#     160                 tokens.long().to(device=self.device),
#     161                 features_only=False,
# --> 162                 return_all_hiddens=False,
#     163             )
#     164         logits = features[0, masked_index, :].squeeze()
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/fairseq/models/roberta/model.py in forward(self, src_tokens, features_only, return_all_hiddens, classification_head_name, **kwargs)
#     102             features_only = True
#     103
# --> 104         x, extra = self.decoder(src_tokens, features_only, return_all_hiddens, **kwargs)
#     105
#     106         if classification_head_name is not None:
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/fairseq/models/roberta/model.py in forward(self, src_tokens, features_only, return_all_hiddens, masked_tokens, **unused)
#     349                   is a list of hidden states.
#     350         """
# --> 351         x, extra = self.extract_features(src_tokens, return_all_hiddens=return_all_hiddens)
#     352         if not features_only:
#     353             x = self.output_layer(x, masked_tokens=masked_tokens)
#
# /usr/local/lib/python3.6/dist-packages/fairseq/models/roberta/model.py in extract_features(self, src_tokens, return_all_hiddens, **unused)
#     357         inner_states, _ = self.sentence_encoder(
#     358             src_tokens,
# --> 359             last_state_only=not return_all_hiddens,
#     360         )
#     361         features = inner_states[-1]
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/fairseq/modules/transformer_sentence_encoder.py in forward(self, tokens, segment_labels, last_state_only, positions)
#     219             dropout_probability = random.uniform(0, 1)
#     220             if not self.training or (dropout_probability > self.layerdrop):
# --> 221                 x, _ = layer(x, self_attn_padding_mask=padding_mask)
#     222                 if not last_state_only:
#     223                     inner_states.append(x)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/fairseq/modules/transformer_sentence_encoder_layer.py in forward(self, x, self_attn_mask, self_attn_padding_mask)
#      84
#      85         residual = x
# ---> 86         x = self.activation_fn(self.fc1(x))
#      87         x = F.dropout(x, p=self.activation_dropout, training=self.training)
#      88         x = self.fc2(x)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#      85
#      86     def forward(self, input):
# ---> 87         return F.linear(input, self.weight, self.bias)
#      88
#      89     def extra_repr(self):
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1370         ret = torch.addmm(bias, input, weight.t())
#    1371     else:
# -> 1372         output = input.matmul(weight.t())
#    1373         if bias is not None:
#    1374             output += bias
#
# KeyboardInterrupt:

# %%
de_het_correct, de_het_total = evaluate_zeroshot_wordlist.evaluate(["de", "het"], model=berdt, print_step=100)
print("De/Het:", de_het_correct/de_het_total)
# Out:
# 63.00% / 63 / 100 / 0 errors / de / De / De eerder beantwoorde vragen betreffen de bijdrage van mevrouw <mask> Palacio over een ander dossier en gaan niet over de uitspraken die 18 november jongstleden in de krant ABC zijn verschenen.
# 66.50% / 133 / 200 / 0 errors / de / de / Daar onze fractie meent dat het <mask> taak is van een parlement om te luisteren, te debatteren en na te denken, geloven wij dat er geen enkele reden is die dit uitstel rechtvaardigt . Ook menen wij dat indien de Commissie in staat is het programma te presenteren, wij zeker nog de tijd hebben om terug te komen op de oorspronkelijke afspraak tussen het Parlement en de Commissie, en tegenover onze medeburgers op verantwoordelijke wijze te werk te gaan.
# 68.00% / 204 / 300 / 0 errors / het / de / ( Het Parlement verwerpt <mask> verzoek met 164 stemmen voor , 166 stemmen tegen en 7 onthoudingen )
# 68.75% / 275 / 400 / 0 errors / de / de / Met onze amendementen uit <mask> eerste lezing is volgens mij in hoge mate rekening gehouden.
# 69.60% / 348 / 500 / 0 errors / de / de / Als we kijken naar <mask> situatie voor de veiligheidsadviseurs, dan is het in een aantal landen per 1 januari van dit jaar verplicht om zo' n veiligheidsadviseur bij bedrijven te hebben.
# 70.67% / 424 / 600 / 0 errors / de / de / Van de week houden wij hier naar aanleiding van de ramp met de Erika een debat over <mask> veiligheid van vervoer over zee, en in de loop van het jaar zullen wij over de veiligheidsdoelstellingen voor het luchtvervoer moeten debatteren.
# 70.71% / 495 / 700 / 0 errors / de / de / Het is goed dat deze richtlijn nu wordt opgesteld, omdat de lidstaten anders hun nationale bepalingen voor zeer korte tijd, voor een overgangsperiode, zouden moeten wijzigen, wat slechts nodeloze kosten met zich meebrengt en de ergernis bij de burgers over <mask> Europese bureaucratie nog groter maakt.
# 69.88% / 559 / 800 / 0 errors / het / de / Wij betreuren het allemaal dat het Europees Comité voor Normalisatie (CEN) niet binnen de vereiste tijd de noodzakelijke wijziging van de bepalingen heeft kunnen voltooien om tot een adequate harmonisatie in <mask> kader van de Europese Unie te komen.
# 70.33% / 633 / 900 / 0 errors / de / de / Een tweede punt waar wij vooral vanuit het oogpunt van de industrie de aandacht aan willen schenken, is dat wij zouden willen zien dat de Commissie, wanneer zij de coördinatie van het Cohesiefonds en <mask> structuurfondsen voorbereidt, meer aandacht schenkt aan het effect van het toenemende gebruik van diensten, elektronische handel en het Internet.

# %%
gebeurt_correct, gebeurt_total, gebeurt_errors = evaluate_zeroshot_wordlist.evaluate(["gebeurt", "gebeurd"], model=berdt, print_step=1)
print("gebeurd/t", gebeurt_correct/gebeurt_total, "Error:" , gebeurt_errors/gebeurt_total)
# Out:
# 0.00% / 0 / 1 / 1 errors / gebeurd / None / Maar, Voorzitter, er is niet <mask> waar ik om had gevraagd.
# 0.00% / 0 / 2 / 2 errors / gebeurd / None / Mevrouw Lynne, u hebt volkomen gelijk . Ik zal nagaan of dit inderdaad niet <mask> is.
# 0.00% / 0 / 3 / 3 errors / gebeurd / None / Dit is niet <mask>.
# 0.00% / 0 / 4 / 4 errors / gebeurd / None / Bij een van de ongelukken die de laatste tijd zijn <mask>, waren de vervoerde goederen op zich niet gevaarlijk; margarine en enkele liters verf, die op zich in beginsel geen risico's inhielden, hebben toen tot een ware ramp geleid.
# Error with Te veel van wat er in dit Parlement <mask> is niet transparant.	0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-3f08ba5b903e> in <module>
# ----> 1 gebeurt_correct, gebeurt_total, gebeurt_errors = evaluate_zeroshot_wordlist.evaluate(["gebeurt", "gebeurd"], model=berdt, print_step=1)
#       2 print("gebeurd/t", gebeurt_correct/gebeurt_total, "Error:" , gebeurt_errors/gebeurt_total)
#       3
#
# ~/Repositories/berdt/src/evaluate_zeroshot_wordlist.py in evaluate(words, path, model, print_step)
#      34
#      35             try:
# ---> 36                 predicted = wordlistfiller.find_optimal_word(sentence)
#      37                 if predicted is None:
#      38                     errors += 1
#
# ~/Repositories/berdt/src/wordlistfiller.py in find_optimal_word(self, text)
#      23         result = None
#      24         while result is None and topk <= self._top_k_limit:
# ---> 25             filler_words = self._model.fill_mask(text, topk=topk)
#      26             result = next((x[2].strip() for x in filler_words if x[2].lower() in self._target_words_spaced), None)
#      27             topk *= 2
#
# /usr/local/lib/python3.6/dist-packages/fairseq/models/roberta/hub_interface.py in fill_mask(self, masked_input, topk)
#     160                 tokens.long().to(device=self.device),
#     161                 features_only=False,
# --> 162                 return_all_hiddens=False,
#     163             )
#     164         logits = features[0, masked_index, :].squeeze()
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/fairseq/models/roberta/model.py in forward(self, src_tokens, features_only, return_all_hiddens, classification_head_name, **kwargs)
#     102             features_only = True
#     103
# --> 104         x, extra = self.decoder(src_tokens, features_only, return_all_hiddens, **kwargs)
#     105
#     106         if classification_head_name is not None:
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/fairseq/models/roberta/model.py in forward(self, src_tokens, features_only, return_all_hiddens, masked_tokens, **unused)
#     349                   is a list of hidden states.
#     350         """
# --> 351         x, extra = self.extract_features(src_tokens, return_all_hiddens=return_all_hiddens)
#     352         if not features_only:
#     353             x = self.output_layer(x, masked_tokens=masked_tokens)
#
# /usr/local/lib/python3.6/dist-packages/fairseq/models/roberta/model.py in extract_features(self, src_tokens, return_all_hiddens, **unused)
#     357         inner_states, _ = self.sentence_encoder(
#     358             src_tokens,
# --> 359             last_state_only=not return_all_hiddens,
#     360         )
#     361         features = inner_states[-1]
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/fairseq/modules/transformer_sentence_encoder.py in forward(self, tokens, segment_labels, last_state_only, positions)
#     219             dropout_probability = random.uniform(0, 1)
#     220             if not self.training or (dropout_probability > self.layerdrop):
# --> 221                 x, _ = layer(x, self_attn_padding_mask=padding_mask)
#     222                 if not last_state_only:
#     223                     inner_states.append(x)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/fairseq/modules/transformer_sentence_encoder_layer.py in forward(self, x, self_attn_mask, self_attn_padding_mask)
#      77             key_padding_mask=self_attn_padding_mask,
#      78             need_weights=False,
# ---> 79             attn_mask=self_attn_mask,
#      80         )
#      81         x = F.dropout(x, p=self.dropout, training=self.training)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/fairseq/modules/multihead_attention.py in forward(self, query, key, value, key_padding_mask, incremental_state, need_weights, static_kv, attn_mask, before_softmax, need_head_weights)
#     133                                                   q_proj_weight=self.q_proj.weight,
#     134                                                   k_proj_weight=self.k_proj.weight,
# --> 135                                                   v_proj_weight=self.v_proj.weight)
#     136
#     137         if incremental_state is not None:
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py in multi_head_attention_forward(query, key, value, embed_dim_to_check, num_heads, in_proj_weight, in_proj_bias, bias_k, bias_v, add_zero_attn, dropout_p, out_proj_weight, out_proj_bias, training, key_padding_mask, need_weights, attn_mask, use_separate_proj_weight, q_proj_weight, k_proj_weight, v_proj_weight, static_k, static_v)
#    3195     """
#    3196
# -> 3197     qkv_same = torch.equal(query, key) and torch.equal(key, value)
#    3198     kv_same = torch.equal(key, value)
#    3199
#
# KeyboardInterrupt:
